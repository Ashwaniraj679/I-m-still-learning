# %%
import pandas as pd

# %% [raw]
# Table extraction

# %%
friends= pd.read_html('https://en.wikipedia.org/wiki/List_of_Friends_episodes')

# %%
len(friends)
# Out:
# 17

# %%
friends[3]
# Out:
#     No.overall  No. inseason  \
# 0           49             1
# 1           50             2
# 2           51             3
# 3           52             4
# 4           53             5
# 5           54             6
# 6           55             7
# 7           56             8
# 8           57             9
# 9           58            10
# 10          59            11
# 11          60            12
# 12          61            13
# 13          62            14
# 14          63            15
# 15          64            16
# 16          65            17
# 17          66            18
# 18          67            19
# 19          68            20
# 20          69            21
# 21          70            22
# 22          71            23
# 23          72            24
# 24          73            25
#
#                                                 Title      Directed by  \
# 0            "The One with the Princess Leia Fantasy"     Gail Mancuso
# 1                      "The One Where No One's Ready"     Gail Mancuso
# 2                              "The One with the Jam"  Kevin S. Bright
# 3              "The One with the Metaphorical Tunnel"  Steve Zuckerman
# 4                            "The One with Frank Jr."  Steve Zuckerman
# 5                        "The One with the Flashback"     Peter Bonerz
# 6                     "The One with the Race Car Bed"     Gail Mancuso
# 7              "The One with the Giant Poking Device"     Gail Mancuso
# 8                         "The One with the Football"  Kevin S. Bright
# 9                        "The One Where Rachel Quits"     Terry Hughes
# 10  "The One Where Chandler Can't Remember Which S...     Terry Hughes
# 11                    "The One with All the Jealousy"     Robby Benson
# 12  "The One Where Monica and Richard Are Just Fri...     Robby Benson
# 13                 "The One with Phoebe's Ex-Partner"     Robby Benson
# 14       "The One Where Ross and Rachel Take a Break"    James Burrows
# 15                   "The One with the Morning After"    James Burrows
# 16                     "The One Without the Ski Trip"        Sam Simon
# 17                   "The One with the Hypnosis Tape"     Robby Benson
# 18                    "The One with the Tiny T-Shirt"     Terry Hughes
# 19                       "The One with the Dollhouse"     Terry Hughes
# 20                  "The One with a Chick and a Duck"  Michael Lembeck
# 21                        "The One with the Screamer"     Peter Bonerz
# 22                        "The One with Ross's Thing"   Shelley Jensen
# 23      "The One with the Ultimate Fighting Champion"     Robby Benson
# 24                             "The One at the Beach"    Pamela Fryman
#
#                                            Written by   Original air date  \
# 0                  Michael Curtis & Gregory S. Malins  September 19, 1996
# 1                                     Ira Ungerleider  September 26, 1996
# 2                                         Wil Calhoun     October 3, 1996
# 3                                         Alexa Junge    October 10, 1996
# 4               Shana Goldberg-Meehan & Scott Silveri    October 17, 1996
# 5                        David Crane & Marta Kauffman    October 31, 1996
# 6                                        Seth Kurland    November 7, 1996
# 7                                          Adam Chase   November 14, 1996
# 8                                     Ira Ungerleider   November 21, 1996
# 9                  Gregory S. Malins & Michael Curtis   December 12, 1996
# 10                                        Alexa Junge     January 9, 1997
# 11                                        Doty Abrams    January 16, 1997
# 12                                     Michael Borkow    January 30, 1997
# 13                                        Wil Calhoun    February 6, 1997
# 14                                     Michael Borkow   February 13, 1997
# 15                       David Crane & Marta Kauffman   February 20, 1997
# 16              Shana Goldberg-Meehan & Scott Silveri       March 6, 1997
# 17                                       Seth Kurland      March 13, 1997
# 18                                         Adam Chase      March 27, 1997
# 19                                        Wil Calhoun      April 10, 1997
# 20                                        Chris Brown      April 17, 1997
# 21              Shana Goldberg-Meehan & Scott Silveri      April 24, 1997
# 22                           Ted Cohen & Andrew Reich         May 1, 1997
# 23  Story by : Pang-Ni Landrum & Mark KunerthTelep...         May 8, 1997
# 24  Story by : Pang-Ni Landrum & Mark KunerthTelep...        May 15, 1997
#
#     Prod.code U.S. viewers(millions) Rating/share(18–49)
# 0      465251              26.76[27]         13.8/42[28]
# 1      465252              26.73[29]         13.3/39[30]
# 2      465253              25.23[31]         12.9/40[32]
# 3      465254              26.10[33]         13.6/40[34]
# 4      465255              23.25[35]         12.1/34[36]
# 5      465256              23.27[37]         12.0/36[38]
# 6      465257              27.36[39]         13.7/38[40]
# 7      465258              28.69[41]         14.3/38[42]
# 8      465259              29.28[43]         15.2/41[44]
# 9      465260              25.10[45]         12.4/36[46]
# 10     465261              29.80[47]         15.3/37[48]
# 11     465262              29.61[49]         15.0/38[50]
# 12     465265              28.03[51]         14.3/38[52]
# 13     465266              28.91[53]         15.2/40[54]
# 14     465263              27.25[55]         13.9/38[56]
# 15     465264              28.26[57]         14.5/40[58]
# 16     465267              25.84[59]         12.9/37[60]
# 17     465269              28.07[61]         13.4/37[62]
# 18     465268              23.65[63]         11.9/38[64]
# 19     465270              24.36[65]         12.6/39[66]
# 20     465271              23.22[67]         11.5/36[68]
# 21     465272              22.63[69]         11.9/37[70]
# 22     465274              24.17[71]         12.9/39[72]
# 23     465273              23.07[73]         12.2/38[74]
# 24     465275              23.39[75]                 NaN

# %%
dir(friends)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
help(friends)
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __reversed__(self, /)
#  |      Return a reverse iterator over the list.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(self, /)
#  |      Return the size of the list in memory, in bytes.
#  |
#  |  append(self, object, /)
#  |      Append object to the end of the list.
#  |
#  |  clear(self, /)
#  |      Remove all items from list.
#  |
#  |  copy(self, /)
#  |      Return a shallow copy of the list.
#  |
#  |  count(self, value, /)
#  |      Return number of occurrences of value.
#  |
#  |  extend(self, iterable, /)
#  |      Extend list by appending elements from the iterable.
#  |
#  |  index(self, value, start=0, stop=9223372036854775807, /)
#  |      Return first index of value.
#  |
#  |      Raises ValueError if the value is not present.
#  |
#  |  insert(self, index, object, /)
#  |      Insert object before index.
#  |
#  |  pop(self, index=-1, /)
#  |      Remove and return item at index (default last).
#  |
#  |      Raises IndexError if list is empty or index is out of range.
#  |
#  |  remove(self, value, /)
#  |      Remove first occurrence of value.
#  |
#  |      Raises ValueError if the value is not present.
#  |
#  |  reverse(self, /)
#  |      Reverse *IN PLACE*.
#  |
#  |  sort(self, /, *, key=None, reverse=False)
#  |      Sort the list in ascending order and return None.
#  |
#  |      The sort is in-place (i.e. the list itself is modified) and stable (i.e. the
#  |      order of two equal elements is maintained).
#  |
#  |      If a key function is given, apply it once to each list item and sort them,
#  |      ascending or descending, according to their function values.
#  |
#  |      The reverse flag can be set to sort in descending order.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  __class_getitem__(...) from builtins.type
#  |      See PEP 585
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %%
#drawing a mandalbrot set
import numpy as np
import matplotlib.pyplot as plt

def mandelbrot(c):
    z = 0
    n = 0
    while abs(z) <= 2 and n < 50:
        z = z*z + c
        n += 1
    return n

x = np.linspace(-2, 1, 1000)
y = np.linspace(-1.5, 1.5, 1000)

X, Y = np.meshgrid(x, y)
C = X + 1j*Y

Z = np.array([mandelbrot(c) for c in C.flat]).reshape(C.shape)

plt.imshow(Z, cmap='hot', extent=[-2, 1, -1.5, 1.5])
plt.show()
