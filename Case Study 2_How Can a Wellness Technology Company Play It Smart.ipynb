# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
path = r"C:\Users\Ashwani Raj\Desktop\Previous 12 months of Cyclistic trip data\Case_study_2\Fitabase Data 4.12.16-5.12.16\dailyActivity_merged.csv"

# %%
activities =pd.read_csv(path, parse_dates=["ActivityDate"])
calories = pd.read_csv(r"C:\Users\Ashwani Raj\Desktop\Previous 12 months of Cyclistic trip data\Case_study_2\Fitabase Data 4.12.16-5.12.16\hourlyCalories_merged.csv",parse_dates=["ActivityHour"])
intensities = pd.read_csv(r"C:\Users\Ashwani Raj\Desktop\Previous 12 months of Cyclistic trip data\Case_study_2\Fitabase Data 4.12.16-5.12.16\hourlyIntensities_merged.csv",parse_dates=["ActivityHour"])
sleep = pd.read_csv(r"C:\Users\Ashwani Raj\Desktop\Previous 12 months of Cyclistic trip data\Case_study_2\Fitabase Data 4.12.16-5.12.16\sleepDay_merged.csv",parse_dates=["SleepDay"])
weight = pd.read_csv(r"C:\Users\Ashwani Raj\Desktop\Previous 12 months of Cyclistic trip data\Case_study_2\Fitabase Data 4.12.16-5.12.16\weightLogInfo_merged.csv",parse_dates=["Date"])

# %% [markdown]
# DATAFRAMES LOADED:
# > activities
# > calories
# > intensities
# > sleep
# > weight

# %%
activities
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-04-12       13162       8.500000         8.500000
# 1    1503960366   2016-04-13       10735       6.970000         6.970000
# 2    1503960366   2016-04-14       10460       6.740000         6.740000
# 3    1503960366   2016-04-15        9762       6.280000         6.280000
# 4    1503960366   2016-04-16       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391   2016-05-08       10686       8.110000         8.110000
# 936  8877689391   2016-05-09       20226      18.250000        18.250000
# 937  8877689391   2016-05-10       10733       8.150000         8.150000
# 938  8877689391   2016-05-11       21420      19.559999        19.559999
# 939  8877689391   2016-05-12        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
activities.shape
# Out:
# (940, 15)

# %%
activities.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489702         5.475351
# std    2.424805e+09   5087.150742       3.924606         3.907276
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.620000         2.620000
# 50%    4.445115e+09   7405.500000       5.245000         5.245000
# 75%    6.962181e+09  10727.000000       7.712500         7.710000
# max    8.877689e+09  36019.000000      28.030001        28.030001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                940.000000          940.000000                940.000000
# mean                   0.108171            1.502681                  0.567543
# std                    0.619897            2.658941                  0.883580
# ...

# %%
activities.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
cx =activities[['Id', 'TotalSteps', 'TotalDistance', 'TrackerDistance', 'VeryActiveDistance',
       'ModeratelyActiveDistance', 'LightActiveDistance',
        'VeryActiveMinutes', 'FairlyActiveMinutes',
       'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories']].groupby('Id').sum().sort_values('TotalDistance', ascending=False)
cx[['TotalSteps']].head(15).plot(kind = 'barh')
# Out:
# <AxesSubplot:ylabel='Id'>

# %%
fig = plt.figure(figsize=(15, 8))
plt.scatter(data = activities , x ="TotalDistance", y = "Calories")
plt.title('Total Distance vs Calories')
plt.xlabel('Total Distance')
plt.ylabel('Calories')
plt.show()

# %%
fig = plt.figure(figsize=(16, 8))
plt.scatter(data = activities, x = "TotalSteps", y = "TotalDistance")
plt.xlabel('Total Distance')
plt.ylabel('Total Steps')
plt.title("TOTAL DISTANCE VS TOTAL STEPS")

plt.show()

# %%
calories
# Out:
#                Id        ActivityHour  Calories
# 0      1503960366 2016-04-12 00:00:00        81
# 1      1503960366 2016-04-12 01:00:00        61
# 2      1503960366 2016-04-12 02:00:00        59
# 3      1503960366 2016-04-12 03:00:00        47
# 4      1503960366 2016-04-12 04:00:00        48
# ...           ...                 ...       ...
# 22094  8877689391 2016-05-12 10:00:00       126
# 22095  8877689391 2016-05-12 11:00:00       192
# 22096  8877689391 2016-05-12 12:00:00       321
# 22097  8877689391 2016-05-12 13:00:00       101
# 22098  8877689391 2016-05-12 14:00:00       113
#
# [22099 rows x 3 columns]

# %%
calories.dtypes
# Out:
# Id                       int64
# ActivityHour    datetime64[ns]
# Calories                 int64
# dtype: object

# %%
intensities
# Out:
#                Id        ActivityHour  TotalIntensity  AverageIntensity
# 0      1503960366 2016-04-12 00:00:00              20          0.333333
# 1      1503960366 2016-04-12 01:00:00               8          0.133333
# 2      1503960366 2016-04-12 02:00:00               7          0.116667
# 3      1503960366 2016-04-12 03:00:00               0          0.000000
# 4      1503960366 2016-04-12 04:00:00               0          0.000000
# ...           ...                 ...             ...               ...
# 22094  8877689391 2016-05-12 10:00:00              12          0.200000
# 22095  8877689391 2016-05-12 11:00:00              29          0.483333
# 22096  8877689391 2016-05-12 12:00:00              93          1.550000
# 22097  8877689391 2016-05-12 13:00:00               6          0.100000
# 22098  8877689391 2016-05-12 14:00:00               9          0.150000
#
# [22099 rows x 4 columns]

# %%
intensities[['TotalIntensity']].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.relplot(data=intensities,x='AverageIntensity',y= 'TotalIntensity')

# %%
sleep
# Out:
#              Id   SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0    1503960366 2016-04-12                  1                 327
# 1    1503960366 2016-04-13                  2                 384
# 2    1503960366 2016-04-15                  1                 412
# 3    1503960366 2016-04-16                  2                 340
# 4    1503960366 2016-04-17                  1                 700
# ..          ...        ...                ...                 ...
# 408  8792009665 2016-04-30                  1                 343
# 409  8792009665 2016-05-01                  1                 503
# 410  8792009665 2016-05-02                  1                 415
# 411  8792009665 2016-05-03                  1                 516
# 412  8792009665 2016-05-04                  1                 439
#
#      TotalTimeInBed
# 0               346
# 1               407
# 2               442
# 3               367
# 4               712
# ..              ...
# 408             360
# ...

# %%
sleep[['TotalSleepRecords']].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='TotalSleepRecords'>

# %%
sleep[['TotalMinutesAsleep','TotalTimeInBed']].plot(kind='hist',alpha=0.4,bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
fig = plt.figure(figsize=(16, 8))
plt.scatter(data = sleep, x = "TotalTimeInBed", y = "TotalMinutesAsleep")
plt.xlabel('Time in Bed')
plt.ylabel('Time Asleep')
plt.title("Time in bed vs Time Asleep")

plt.show()

# %%
sleep.dtypes
# Out:
# Id                             int64
# SleepDay              datetime64[ns]
# TotalSleepRecords              int64
# TotalMinutesAsleep             int64
# TotalTimeInBed                 int64
# dtype: object

# %%
weight
# Out:
#             Id                Date    WeightKg  WeightPounds   Fat        BMI  \
# 0   1503960366 2016-05-02 23:59:59   52.599998    115.963147  22.0  22.650000
# 1   1503960366 2016-05-03 23:59:59   52.599998    115.963147   NaN  22.650000
# 2   1927972279 2016-04-13 01:08:52  133.500000    294.317120   NaN  47.540001
# 3   2873212765 2016-04-21 23:59:59   56.700001    125.002104   NaN  21.450001
# 4   2873212765 2016-05-12 23:59:59   57.299999    126.324875   NaN  21.690001
# ..         ...                 ...         ...           ...   ...        ...
# 62  8877689391 2016-05-06 06:43:35   85.000000    187.392923   NaN  25.440001
# 63  8877689391 2016-05-08 07:35:53   85.400002    188.274775   NaN  25.559999
# 64  8877689391 2016-05-09 06:39:44   85.500000    188.495234   NaN  25.610001
# 65  8877689391 2016-05-11 06:51:47   85.400002    188.274775   NaN  25.559999
# 66  8877689391 2016-05-12 06:42:53   84.000000    185.188300   NaN  25.139999
#
# ...

# %%
weight['WeightKg'] = weight['WeightKg'].round(2)
weight['WeightPounds'] = weight['WeightPounds'].round(2)
weight['BMI'] = weight['BMI'].round(3)
weight
# Out:
#             Id                Date  WeightKg  WeightPounds   Fat    BMI  \
# 0   1503960366 2016-05-02 23:59:59      52.6        115.96  22.0  22.65
# 1   1503960366 2016-05-03 23:59:59      52.6        115.96   NaN  22.65
# 2   1927972279 2016-04-13 01:08:52     133.5        294.32   NaN  47.54
# 3   2873212765 2016-04-21 23:59:59      56.7        125.00   NaN  21.45
# 4   2873212765 2016-05-12 23:59:59      57.3        126.32   NaN  21.69
# ..         ...                 ...       ...           ...   ...    ...
# 62  8877689391 2016-05-06 06:43:35      85.0        187.39   NaN  25.44
# 63  8877689391 2016-05-08 07:35:53      85.4        188.27   NaN  25.56
# 64  8877689391 2016-05-09 06:39:44      85.5        188.50   NaN  25.61
# 65  8877689391 2016-05-11 06:51:47      85.4        188.27   NaN  25.56
# 66  8877689391 2016-05-12 06:42:53      84.0        185.19   NaN  25.14
#
#     IsManualReport          LogId
# 0             True  1462233599000
# ...

# %%
weight = weight[['Id', 'Date', 'WeightKg', 'WeightPounds','BMI','IsManualReport', 'LogId']]
weight
# Out:
#             Id                Date  WeightKg  WeightPounds    BMI  \
# 0   1503960366 2016-05-02 23:59:59      52.6        115.96  22.65
# 1   1503960366 2016-05-03 23:59:59      52.6        115.96  22.65
# 2   1927972279 2016-04-13 01:08:52     133.5        294.32  47.54
# 3   2873212765 2016-04-21 23:59:59      56.7        125.00  21.45
# 4   2873212765 2016-05-12 23:59:59      57.3        126.32  21.69
# ..         ...                 ...       ...           ...    ...
# 62  8877689391 2016-05-06 06:43:35      85.0        187.39  25.44
# 63  8877689391 2016-05-08 07:35:53      85.4        188.27  25.56
# 64  8877689391 2016-05-09 06:39:44      85.5        188.50  25.61
# 65  8877689391 2016-05-11 06:51:47      85.4        188.27  25.56
# 66  8877689391 2016-05-12 06:42:53      84.0        185.19  25.14
#
#     IsManualReport          LogId
# 0             True  1462233599000
# 1             True  1462319999000
# 2            False  1460509732000
# ...
