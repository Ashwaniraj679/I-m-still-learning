# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Holdings.csv')

# %%
df.head(10)
# Out:
#     Security  No. of Smallcases  Quantity  Average Cost ₹  Portfolio Weight %  \
# 0      DABUR                0.0       1.0          532.30                2.18
# 1        BCG                0.0       1.0           25.00                0.10
# 2      MSUMI                0.0       1.0           85.45                0.21
# 3        RCF                0.0       3.0          130.87                1.36
# 4  REDINGTON                0.0       1.0          167.50                0.73
# 5       SBIN                0.0       1.0          539.45                2.16
# 6       GSFC                0.0       1.0          128.25                0.52
# 7    HCLTECH                0.0       1.0         1067.30                4.52
# 8       GAIL                0.0      70.0          102.32               27.35
# 9        IEX                0.0       2.0          145.35                1.10
#
#      LTP ₹  Invested Value ₹  Current Value ₹  P & L ₹  Net Change %  \
# 0   534.50            532.30           534.50     2.20          0.41
# 1    24.70             25.00            24.70    -0.30         -1.20
# 2    50.80             85.45            50.80   -34.65        -40.55
# 3   111.15            392.61           333.45   -59.16        -15.07
# 4   179.85            167.50           179.85    12.35          7.37
# 5   531.00            539.45           531.00    -8.45         -1.57
# 6   128.40            128.25           128.40     0.15          0.12
# 7  1109.55           1067.30          1109.55    42.25          3.96
# 8    96.00           7162.40          6720.00  -442.40         -6.18
# 9   135.45            290.70           270.90   -19.80         -6.81
#
#    Daily Change ₹  Daily Change %
# 0           -1.10           -0.21
# 1           -0.75           -2.95
# 2            0.25            0.49
# 3           -1.70           -1.51
# 4           -0.30           -0.17
# 5           -9.10           -1.68
# 6            0.05            0.04
# 7          -18.60           -1.65
# 8            0.05            0.05
# 9           -0.70           -0.51

# %%
df.shape
# Out:
# (31, 12)

# %%
df= df.drop('No. of Smallcases',axis = 1)
df.head()
# Out:
#     Security  Quantity  Average Cost ₹  Portfolio Weight %   LTP ₹  \
# 0      DABUR       1.0          532.30                2.18  534.50
# 1        BCG       1.0           25.00                0.10   24.70
# 2      MSUMI       1.0           85.45                0.21   50.80
# 3        RCF       3.0          130.87                1.36  111.15
# 4  REDINGTON       1.0          167.50                0.73  179.85
#
#    Invested Value ₹  Current Value ₹  P & L ₹  Net Change %  Daily Change ₹  \
# 0            532.30           534.50     2.20          0.41           -1.10
# 1             25.00            24.70    -0.30         -1.20           -0.75
# 2             85.45            50.80   -34.65        -40.55            0.25
# 3            392.61           333.45   -59.16        -15.07           -1.70
# 4            167.50           179.85    12.35          7.37           -0.30
#
#    Daily Change %
# 0           -0.21
# 1           -2.95
# 2            0.49
# 3           -1.51
# 4           -0.17

# %%
df.shape
# Out:
# (31, 11)

# %%
df.describe()
# Out:
#         Quantity  Average Cost ₹  Portfolio Weight %        LTP ₹  \
# count  31.000000       31.000000           31.000000    31.000000
# mean    4.645161      310.578387            3.226452   310.422581
# std    12.451368      278.191523            4.959222   285.519288
# min     1.000000       25.000000            0.100000    24.700000
# 25%     1.000000      129.560000            0.730000   119.675000
# 50%     1.000000      170.800000            1.960000   179.850000
# 75%     3.000000      448.115000            3.870000   417.900000
# max    70.000000     1070.200000           27.350000  1129.200000
#
#        Invested Value ₹  Current Value ₹     P & L ₹  Net Change %  \
# count         31.000000        31.000000   31.000000     31.000000
# mean         802.214516       792.566129   -9.648387     -1.268710
# std         1284.832812      1218.538178   89.367612     10.350414
# min           25.000000        24.700000 -442.400000    -40.550000
# 25%          169.150000       179.450000  -23.020000     -4.510000
# 50%          494.000000       482.700000    0.150000      0.120000
# 75%          884.350000       950.775000   21.130000      4.045000
# max         7162.400000      6720.000000  100.040000     15.000000
#
#        Daily Change ₹  Daily Change %
# count       31.000000       31.000000
# mean        -1.816129       -0.334839
# std          5.160384        1.459902
# min        -18.600000       -2.950000
# 25%         -2.600000       -1.280000
# 50%         -0.700000       -0.220000
# 75%          0.100000        0.115000
# max          7.350000        4.970000
