# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Holdings.csv')

# %%
df.head(10)
# Out:
#     Security  No. of Smallcases  Quantity  Average Cost ₹  Portfolio Weight %  \
# 0      DABUR                0.0       1.0          532.30                2.18
# 1        BCG                0.0       1.0           25.00                0.10
# 2      MSUMI                0.0       1.0           85.45                0.21
# 3        RCF                0.0       3.0          130.87                1.36
# 4  REDINGTON                0.0       1.0          167.50                0.73
# 5       SBIN                0.0       1.0          539.45                2.16
# 6       GSFC                0.0       1.0          128.25                0.52
# 7    HCLTECH                0.0       1.0         1067.30                4.52
# 8       GAIL                0.0      70.0          102.32               27.35
# 9        IEX                0.0       2.0          145.35                1.10
#
#      LTP ₹  Invested Value ₹  Current Value ₹  P & L ₹  Net Change %  \
# ...

# %%
df.columns
# Out:
# Index(['Security', 'No. of Smallcases', 'Quantity', 'Average Cost ₹',
#        'Portfolio Weight %', 'LTP ₹', 'Invested Value ₹', 'Current Value ₹',
#        'P & L ₹', 'Net Change %', 'Daily Change ₹', 'Daily Change %'],
#       dtype='object')

# %%
updated_columns = {'Security', 'Quantity', 'Average Cost', 'Portfolio Weight %', 'LTP',
       'Invested Value', 'Current Value', 'P & L', 'Net Change %',
       'Daily Change', 'Daily Change %'}
df.set_axis({'Security', 'No. of Smallcases','Quantity', 'Average Cost', 'Portfolio Weight %', 'LTP',
       'Invested Value', 'Current Value', 'P & L', 'Net Change %',
       'Daily Change', 'Daily Change %'},axis = 1, inplace = True)
# Out:
# C:\Users\ASHWAN~1\AppData\Local\Temp/ipykernel_21040/2274496747.py:4: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   df.set_axis({'Security', 'No. of Smallcases','Quantity', 'Average Cost', 'Portfolio Weight %', 'LTP',

# %%
df.shape
# Out:
# (31, 12)

# %%
df= df.drop('No. of Smallcases',axis = 1)
df.head()
# Out:
#   Net Change %  Daily Change  P & L  Portfolio Weight %  Current Value  \
# 0        DABUR           0.0    1.0              532.30           2.18
# 1          BCG           0.0    1.0               25.00           0.10
# 2        MSUMI           0.0    1.0               85.45           0.21
# 3          RCF           0.0    3.0              130.87           1.36
# 4    REDINGTON           0.0    1.0              167.50           0.73
#
#    Daily Change %  Security  Invested Value  Average Cost    LTP  Quantity
# 0          534.50    532.30          534.50          2.20   0.41     -1.10
# 1           24.70     25.00           24.70         -0.30  -1.20     -0.75
# 2           50.80     85.45           50.80        -34.65 -40.55      0.25
# 3          111.15    392.61          333.45        -59.16 -15.07     -1.70
# 4          179.85    167.50          179.85         12.35   7.37     -0.30

# %%
df.shape
# Out:
# (31, 11)

# %%
df.describe()
# Out:
#        Daily Change      P & L  Portfolio Weight %  Current Value  \
# count          31.0  31.000000           31.000000      31.000000
# mean            0.0   4.645161          310.578387       3.226452
# std             0.0  12.451368          278.191523       4.959222
# min             0.0   1.000000           25.000000       0.100000
# 25%             0.0   1.000000          129.560000       0.730000
# 50%             0.0   1.000000          170.800000       1.960000
# 75%             0.0   3.000000          448.115000       3.870000
# max             0.0  70.000000         1070.200000      27.350000
#
#        Daily Change %     Security  Invested Value  Average Cost        LTP  \
# count       31.000000    31.000000       31.000000     31.000000  31.000000
# mean       310.422581   802.214516      792.566129     -9.648387  -1.268710
# std        285.519288  1284.832812     1218.538178     89.367612  10.350414
# ...

# %%
df[["Security" ,"Quantity", "Invested Value", "Current Value"]]
# Out:
#     Security  Quantity  Invested Value  Current Value
# 0     532.30     -1.10          534.50           2.18
# 1      25.00     -0.75           24.70           0.10
# 2      85.45      0.25           50.80           0.21
# 3     392.61     -1.70          333.45           1.36
# 4     167.50     -0.30          179.85           0.73
# 5     539.45     -9.10          531.00           2.16
# 6     128.25      0.05          128.40           0.52
# 7    1067.30    -18.60         1109.55           4.52
# 8    7162.40      0.05         6720.00          27.35
# 9     290.70     -0.70          270.90           1.10
# 10    140.80      7.35          155.15           0.63
# 11    131.95     -3.15          127.10           0.52
# 12    145.10     -2.05          148.90           0.61
# 13   2011.15     -3.60         2031.50           8.27
# 14    202.24     -0.55          200.40           0.82
# 15    494.00     -5.20          429.50           1.75
# ...
